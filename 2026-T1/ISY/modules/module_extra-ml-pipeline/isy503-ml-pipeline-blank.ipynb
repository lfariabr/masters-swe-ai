# %% [markdown]
# # ML Pipelines: From Excel to Prediction
# ### ISY503 — Blank Worksheet (fill this in yourself)
#
# > Work through each cell. When you're done, compare against the reference notebook.
#
# - **P.** Python & Google Colab Crash Course
# - **0.** Setup & Imports
# - **1.** EDA — the Excel mindset
# - **2.** Data Cleaning & Feature Engineering
# - **3.** Algorithm 1 — Linear Regression
# - **4.** Algorithm 2 — Decision Tree
# - **5.** Algorithm 3 — KNN
# - **6.** Comparison Table
# - **7.** [Optional] Random Forest
# - **8.** [Optional] SVM

# %% [markdown]
# ---
# ## Section P — Python & Google Colab Crash Course
#
# ### What is Google Colab?
#
# Google Colab is a **free coding environment that runs entirely in your browser** — no installation, no setup, no "it works on my machine" problems.
#
# - Real Python environment hosted on Google's servers
# - Every library we need (`pandas`, `sklearn`, `matplotlib`) is already installed
# - Share it like a Google Doc
# - Saved automatically to Google Drive
#
# **How to run a cell:** click ▶ on the left, or press `Shift + Enter`
#
# > ⚠️ Run cells **top to bottom** — later cells depend on earlier ones.

# %% [markdown]
# ### P.1 — `print()`
#
# `print()` displays something on the screen. It's the "say out loud" command.

# %%
# Print "Hello, world!" and two more lines of your choice

# %% [markdown]
# ### P.2 — Variables and Basic Math
#
# A **variable** is a named box that holds a value. You create one with `=`.
#
# Python supports: `+`, `-`, `*`, `/`, `**` (power), `//` (floor division), `%` (remainder).

# %%
# Create 4 variables: name (string), year (int), passengers (int), survival_rate (float)
# Print each one with a label

# %%
# Pick two numbers a and b
# Print the result of every math operator listed above, with a label for each

# %%
# Using the variables from the first cell:
# Calculate how many passengers survived (int) and how many died
# Print them using f-strings (f"text {variable} more text")

# %% [markdown]
# ### P.3 — Importing a Library
#
# ```python
# import library_name                      # full import
# import library_name as alias             # with shorthand
# from library_name import specific_tool   # just one tool
# ```

# %%
# Import Python's built-in 'math' library
# Use it to compute: square root of 16, the value of pi, ceil(3.2), floor(3.9)

# %%
# Import Python's built-in 'random' library
# Set seed to 42
# Print: a random integer between 1-10, a random choice from a list, a shuffled list

# %% [markdown]
# ### P.4 — pandas: Working with Tables in Python
#
# **pandas** gives you `DataFrame` — a table like Excel, but in Python.
# - Rows = records | Columns = features
# - Convention: `import pandas as pd`

# %%
# Import pandas as pd
# Create a DataFrame manually with 5 rows and 4 columns: name, age, class, survived
# Print it

# %%
# On that DataFrame, print:
#   - its shape
#   - its column names as a list
#   - the data types of each column
#   - the statistical summary

# %%
# Select just the 'age' column and print it
# Print the average age and the oldest passenger's age
# Filter: show only rows where survived == 1
# Filter: show only 1st class passengers who survived

# %%
# Use groupby to compute:
#   - survival rate by class
#   - average age by class

# %% [markdown]
# ### P.5 — How to Find Help
#
# - `help(function)` — built-in docs in the notebook
# - `df.something?` — Colab sidebar docs
# - https://pandas.pydata.org/docs/

# %%
# Call help() on a pandas function of your choice

# %%
# Import seaborn as sns
# Load the real titanic dataset using seaborn
# Print its statistical summary for: age, fare, pclass, survived

# %% [markdown]
# ### ✅ Crash Course Done — on to the pipeline ↓

# %% [markdown]
# ---
# ## Section 0 — Setup & Imports
#
# Import everything the pipeline needs in one cell. Run this before anything else.

# %%
# Import: pandas, seaborn, matplotlib.pyplot
# From sklearn import: train_test_split, LabelEncoder,
#   LinearRegression, DecisionTreeClassifier, plot_tree,
#   KNeighborsClassifier, accuracy_score, classification_report, confusion_matrix
# Suppress warnings
# Print a confirmation message

# %% [markdown]
# ---
# ## Section 1 — EDA: The Excel Mindset
#
# Before any ML: **"What would a pivot table tell us?"**
#
# Features: `pclass`, `sex`, `age`, `sibsp`, `parch`, `fare` | Target: `survived` (1 = yes, 0 = no)

# %%
# Load the Titanic dataset via seaborn (one line, no download)
# Print: shape, value counts for 'survived', overall survival rate
# Show the first 5 rows

# %%
# Compute survival rate by: sex, pclass
# Create an age_band column (bins: 0-12, 12-18, 18-35, 35-60, 60-100)
# Compute survival rate by age_band
# Print each result with a clear label

# %%
# Create a 1x3 figure (3 bar charts side by side):
#   1. Survival rate by sex
#   2. Survival rate by ticket class
#   3. Survival rate by age band
# Add title, labels, and percentage annotations on the bars

# %% [markdown]
# ---
# ## Section 2 — Data Cleaning & Feature Engineering
#
# **Suitcase analogy:** fold the clothes (encode), fill the gaps (impute), drop what doesn't fit (nulls).
#
# ML algorithms only understand **numbers** — no text, no nulls.

# %%
# Select only these columns: survived, pclass, sex, age, sibsp, parch, fare
# Print missing value counts per column

# %%
# Step 1: fill missing age values with the median
# Step 2: encode 'sex' from text to numbers using LabelEncoder
# Step 3: drop any remaining rows with nulls
# Print the resulting shape and confirm zero nulls remain
# Show first 5 rows

# %%
# Define X (features) and y (target: survived)
# Split into train/test with 80/20 ratio and random_state=42
# Print the size of each split and the feature list

# %% [markdown]
# ---
# ## Section 3 — Algorithm 1: Linear Regression (Baseline)
#
# Fits the best straight line through the data. Great for continuous outputs. We'll see why it struggles with binary classification.
#
# **The catch:** it can predict values outside [0, 1].

# %%
# Create a LinearRegression model, fit it on the training data
# Predict on the test set
# Print the first 15 raw predictions (rounded to 3 decimal places)
# Print the min and max predicted values — notice anything odd?

# %%
# Apply a 0.5 threshold: predictions >= 0.5 → 1, else → 0
# Compute and print accuracy
# List 2 strengths and 2 weaknesses of using Linear Regression for this problem

# %% [markdown]
# ---
# ## Section 4 — Algorithm 2: Decision Tree
#
# Learns a flowchart of if/else rules from the data. Only predicts valid classes.
#
# **Superpower:** you can read and visualize every decision it makes.

# %%
# Train a DecisionTreeClassifier with max_depth=3 and random_state=42
# Predict on the test set
# Print accuracy and the improvement vs Linear Regression

# %%
# Visualize the tree using plot_tree()
# Include: feature names, class names ['Died (0)', 'Survived (1)'], filled=True, rounded=True
# Add a title

# %%
# Print the full classification_report (with 'Died' and 'Survived' as target names)
# Compute the confusion matrix
# Plot it as a heatmap using seaborn
# Print a human-readable breakdown: TP, TN, FP, FN counts

# %% [markdown]
# ---
# ## Section 5 — Algorithm 3: K-Nearest Neighbors (KNN)
#
# **Canteen analogy:** ask the 5 most similar students whether they like the food → go with the majority.
#
# For Titanic: find the k most similar passengers in training data → predict the majority outcome.

# %%
# Train KNeighborsClassifier with n_neighbors=5
# Predict on the test set
# Print accuracy
# Write out (as comments or print statements) the 4 steps KNN takes to make a prediction

# %%
# Loop k from 1 to 20: train KNN with each k, collect accuracy on the test set
# Plot k (x-axis) vs accuracy (y-axis) as a line chart
# Add a vertical dashed line at k=5

# %% [markdown]
# ---
# ## Section 6 — Comparison: All 3 Algorithms

# %%
# Build a comparison DataFrame with columns:
#   Algorithm, Accuracy, 'Designed for classification?', Interpretability, Key Strength, Key Weakness
# Print it
# Plot a bar chart with the 3 accuracy values, labelled with percentages

# %% [markdown]
# ---
# ## [Optional] Section 7 — Random Forest
#
# **Voting booth analogy:** 100 different Decision Trees each vote. The majority wins.
#
# Different trees see different subsets of data/features → different errors → errors cancel out.

# %%
# Import RandomForestClassifier
# Train with 100 estimators and random_state=42
# Print accuracy and improvement over the single Decision Tree

# %%
# Extract feature_importances_ from the Random Forest
# Store as a pandas Series with feature names as the index
# Sort descending and plot as a bar chart
# Print which feature was most important

# %% [markdown]
# ---
# ## [Optional] Section 8 — Support Vector Machine (SVM)
#
# **Road analogy:** SVM draws the widest possible road between the two classes.
#
# The boundary = **hyperplane**. The road width = **margin**. SVM maximizes the margin.
#
# Needs feature scaling — distances are sensitive to the scale of each feature.

# %%
# Import: LinearSVC, StandardScaler, Pipeline
# Build a Pipeline: first step StandardScaler, second step LinearSVC
# Train on X_train/y_train, predict on X_test
# Print accuracy and explain in a comment why scaling is necessary for SVM

# %%
# Build a final comparison DataFrame with all 5 algorithms:
#   Linear Regression, Decision Tree, KNN, Random Forest, SVM
#   Columns: Algorithm, Accuracy, Type, Interpretability
# Print it
# Print a closing confirmation message

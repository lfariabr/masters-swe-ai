# %%
import pandas as pd

# %%
file = '/Users/luisfaria/Desktop/sEngineer/masters_SWEAI/T1-SEP/assignments/Assessment_2/pro-corpo-nps.xlsx'
nps_pro_corpo = pd.read_excel(file, sheet_name='data')

# %%
nps_pro_corpo.sample(10)

# 1. Classify NPS from 0 to 10
# Out:
#                          Date            Score  \
# 24186 2024-07-26 11:53:00.467          8 - Bom
# 12624 2023-08-01 10:59:43.814          8 - Bom
# 8115  2022-12-05 09:16:53.815        9 - Ótimo
# 22488 2024-06-20 13:38:57.544  10 - Excelente!
# 25236 2024-08-20 17:45:28.714        9 - Ótimo
# 10786 2023-04-24 13:38:47.034        9 - Ótimo
# 17921 2024-02-02 11:13:22.780  10 - Excelente!
# 25477 2024-09-02 19:20:29.025  10 - Excelente!
# 11950 2023-06-26 14:04:04.155        9 - Ótimo
# 21890 2024-06-10 15:50:03.924        9 - Ótimo
#
#                                                  Comment  \
# 24186                                                NaN
# 12624                                         Não tenho!
# 8115                                                 NaN
# 22488                            Estou muito satisfeita
# 25236  Sim. Antes de votar para fazer o atendimento r...
# 10786                                                NaN
# ...

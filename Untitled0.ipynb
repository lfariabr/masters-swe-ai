# %%
import pandas as pd

# %%
link = '/content/pro-corpo-nps_v3 - data.csv'

# %%
df = pd.read_csv(link)

# %%
df
# Out:
#                   Date  Score            Store  Year  \
# 0   02/1/2022 13:04:01     10          Tatuapé  2022
# 1   02/2/2022 12:54:02      9          Tatuapé  2022
# 2   02/2/2022 15:12:20     10         Tucuruvi  2022
# 3   02/2/2022 16:00:41     10         Sorocaba  2022
# 4   02/2/2022 18:35:15     10           Tijuca  2022
# ..                 ...    ...              ...   ...
# 95   02/7/2022 8:54:08     10      Santo Amaro  2022
# 96   02/7/2022 8:54:17     10         Ipiranga  2022
# 97   02/7/2022 8:54:22      9         Campinas  2022
# 98   02/7/2022 8:54:24     10           Tijuca  2022
# 99   02/7/2022 8:54:32     10  Barra da Tijuca  2022
#
#                                               Comment
# 0                                           Very good
# 1                             Very good, no criticism
# 2              Exceptional service by the entire team
# 3                                                  Om
# ...
